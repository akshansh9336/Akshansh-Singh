# %% [markdown]
# <a href="https://colab.research.google.com/github/akshansh9336/Akshansh-Singh/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
array = np.array([[10,20],[30,40],[50,60],[70,80]])
print(array)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]
#  [70 80]]

# %%
print(array.ndim)
# Out:
# 2

# %%
print(array.shape)
# Out:
# (4, 2)

# %%
print(array.shape)
print(array.size)
print(array.dtype)
# Out:
# (4, 2)
# 8
# int64

# %%
array = np.array([[10,20,30],[60,40,50]])
print(array)
# Out:
# [[10 20 30]
#  [60 40 50]]

# %%
array =np.array([[10,20,30,40,50]])
print(array)
# Out:
# [[10 20 30 40 50]]

# %%
print(array[0,0])
# Out:
# 10

# %%
print(array[1:3])
# Out:
# []

# %%
a=np.array([10,20,30])
print(a)
# Out:
# [10 20 30]

# %%
b=np.array([70,80,90])
print(b)
# Out:
# [70 80 90]

# %%
print(a+b)
print(b-a)
print(a*b)
print(a/b)
print(a**2)
# Out:
# [ 80 100 120]
# [60 60 60]
# [ 700 1600 2700]
# [0.14285714 0.25       0.33333333]
# [100 400 900]

# %%
print(np.sqrt(a))     # to find the sq root
print(np.power(a,3))  # for n exponent
# Out:
# [3.16227766 4.47213595 5.47722558]
# [ 1000  8000 27000]
